# %%
import pandas as pd

# %%
csv = pd.read_csv("noticias_g1_200cliks_1610b.csv")
df = pd.DataFrame(csv)

# %%
df
# Out:
#       Local Problema                                             Título  \
# 0  comércio    vazia  'Ruas vazias, comércio fechado, aulas suspensa...
#
#          Data                                               Link
# 0  Há 8 horas  https://g1.globo.com/sc/santa-catarina/noticia...
